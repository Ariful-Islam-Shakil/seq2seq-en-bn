# %%
import torch 

from models.encoder import Encoder
from models.decoder import Decoder
from models.seq2seq import Seq2Seq
from models.attention import Attention
from tokenizer.tokenizer import Tokenizer
from tokenizer.vocab import Vocabulary
from utils.constants import SOS_IDX, EOS_IDX

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

EMBED_DIM = 256
HIDDEN_DIM =  512
MAX_LEN = 50

def load_model(src_vocab_size, tgt_vocab_size):
    encoder = Encoder(src_vocab_size, EMBED_DIM, HIDDEN_DIM)
    attention = Attention(HIDDEN_DIM)
    decoder = Decoder(tgt_vocab_size, EMBED_DIM, HIDDEN_DIM, attention)

    model = Seq2Seq(encoder, decoder, DEVICE).to(DEVICE)
    model.load_state_dict(torch.load("checkpoints/seq2seq_en_bn.pt", map_location=DEVICE, weights_only=True))
    model.eval()
    return model

def translate_sentence(model, src_tokenizer, tgt_tokenizer, sentence):
    tokens = src_tokenizer.encode(sentence)
    src_tensor = torch.tensor(tokens).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        encoder_outputs, hidden = model.encode(src_tensor)
    input_token = torch.tensor([SOS_IDX]).to(DEVICE)
    outputs = []

    for _ in range(MAX_LEN):
        with torch.no_grad():
            output, hidden = model.decode(input_token, hidden, encoder_outputs)
        pred_token = output.argmax(1).item()
        if pred_token == EOS_IDX:
            break
        outputs.append(pred_token)
        input_token = torch.tensor([pred_token]).to(DEVICE)
    
    print(f"\n\ntoken number of output: {len(outputs)}\n\n")
    return tgt_tokenizer.decode(outputs)




print("Loading vocab...\n")
src_vocab = torch.load("tokenizer/src_vocab.pt", weights_only=False)
tgt_vocab = torch.load("tokenizer/tgt_vocab.pt", weights_only=False)

src_tokenizer = Tokenizer(src_vocab)
tgt_tokenizer = Tokenizer(tgt_vocab)
model = load_model(len(src_vocab), len(tgt_vocab))
print("Model loaded successfully!\n")

# sentence = input("\nEnter an English sentence: ")
sentence = "love is beautiful"
translation = translate_sentence(model, src_tokenizer, tgt_tokenizer, sentence)
print(f"Translated Bengali sentence: {translation}")
# Out:
# Loading vocab...
#
# Model loaded successfully!
#
#
#
# token number of output: 50
#
#
# Translated Bengali sentence: ভালোবাসা প্রেম ভালোবাসা প্রেমের ভালোবাসা প্রেমের ভালোবাসা প্রেম ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা ভালোবাসা

# %%
while True:
    sentence = input("\nEnter an English sentence: ")
    if sentence.lower() in ['exit', 'quit', 'q']:
        print("Exiting the translator. Goodbye!")
        break
    translation = translate_sentence(model, src_tokenizer, tgt_tokenizer, sentence)
    print(f"Translated Bengali sentence: {translation}")
    tmp = False
# Out:
# token number of output: 17
#
#
# Translated Bengali sentence: আপনাকে জানায়, এটা ইংল্যান্ডের করার জন্য মাত্র ১৪টি, বিপন্ন হলো আমার মাল, হযরতজী সাদ ছাহেব দেয়। দেয়।
#
#
# token number of output: 14
#
#
# Translated Bengali sentence: আপনি আপনি আপনাকে ইচ্ছুক মানুষ এখন আপনি আপনি সিবিআই, আপনি কয়েক গেলেই আপনাকে জানায়,
#
#
# token number of output: 14
#
#
# Translated Bengali sentence: আপনি আপনি আপনাকে ইচ্ছুক মানুষ এখন আপনি আপনি সিবিআই, আপনি কয়েক গেলেই আপনাকে জানায়,
#
#
# token number of output: 50
#
#
# Translated Bengali sentence: সেরা সেরা সেরা সেরা সেরা সেরা সেরা সেরা দলগুলির সেরা সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির সেরা দলগুলির
#
#
# token number of output: 21
#
#
# Translated Bengali sentence: আপনাকে জানায়, এটা ইংল্যান্ডের করার জন্য মাত্র ১৪টি, হোম কষ্ট কষ্ট কষ্ট করে দিতে পারেন, পালন করে দায়িত্ব পালন করার দেয়।
#
#
# token number of output: 17
#
#
# Translated Bengali sentence: আপনাকে জানায়, এটা ইংল্যান্ডের করার জন্য মাত্র ১৪টি, বিপন্ন হলো আমার মাল, হযরতজী সাদ ছাহেব দেয়। দেয়।
#
#
# token number of output: 21
#
#
# Translated Bengali sentence: আপনাকে জানায়, এটা ইংল্যান্ডের করার জন্য মাত্র ১৪টি, হোম কষ্ট কষ্ট কষ্ট করে দিতে পারেন, পালন করে দায়িত্ব পালন করার দেয়।
#
#
# token number of output: 12
#
#
# Translated Bengali sentence: নারীকে নারী হলেন আরো শিক্ষিত। এ বেশি গুরুত্ব আরো শিক্ষিত। বেশি রয়েছে।
#
#
# token number of output: 14
#
#
# Translated Bengali sentence: প্রতিষ্ঠানটিতে গ্রাফিক ডিজাইনার এক হাজার ষষ্ঠ অনুষ্ঠিত হলে একজন সালে ভারতে করা হবে। হবে।
#
#
# token number of output: 27
#
#
# Translated Bengali sentence: এ সময় তারা করেছে এ বিষয়ে প্রকাশ করেছে এবং করেছে করেছে এ বিধান এ বিধান প্রকাশ করেছে এবং করেছে করেছে করেছে এবং সমগ্র করেছে করেছে আলোচনা করেছেন।
#
#
# token number of output: 27
#
#
# Translated Bengali sentence: এ সময় তারা করেছে এ বিষয়ে প্রকাশ করেছে এবং করেছে করেছে এ বিধান এ বিধান প্রকাশ করেছে এবং করেছে করেছে করেছে এবং সমগ্র করেছে করেছে আলোচনা করেছেন।
# Exiting the translator. Goodbye!
